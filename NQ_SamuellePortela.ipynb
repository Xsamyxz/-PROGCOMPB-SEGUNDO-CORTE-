# %% [markdown]
# **Reporte de perfilamiento de variables**
#
# > Bloc con sangría

# %%
# !pip uninstall pandas
# !pip install "pandas==1.3.5"
# %pylab inline
# Out:
# Found existing installation: pandas 0.25.3
# Uninstalling pandas-0.25.3:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/pandas-0.25.3.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/pandas/*
# Proceed (y/n)? y
#   Successfully uninstalled pandas-0.25.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.3 MB 6.4 MB/s
# ...
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Cargar el CSV (o excel o tabla de datos)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-abb25e24-ff32-400d-a374-177caf0e3c1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abb25e24-ff32-400d-a374-177caf0e3c1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Importar los datos a GC

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import pandas as pd
df = pd.read_excel('tabla de datos determinacion de proteinas.xlsx')
df.head()
# Out:
#      ug   ul   abs1   abs2    prom     abs
# 0     0    0  0.035  0.036  0.0355  0.0000
# 1   500   25  0.123  0.150  0.1365  0.1010
# 2  1000   50  0.225  0.237  0.2310  0.1955
# 3  1500   75  0.328  0.333  0.3305  0.2950
# 4  2000  100  0.420  0.398  0.4090  0.3735

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.heatmap(df.isnull())

# %%
from pandas_profiling import ProfileReport
from seaborn import lmplot

# %%
lmplot('prom','abs',data=df,fit_reg=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(df['abs2'],bins=60,kde=True)

# %%
sns.set_theme(style="whitegrid")
diamonds = sns.load_dataset("diamonds")

f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
